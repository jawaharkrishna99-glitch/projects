# %%
Num1=10
Num2=30
add=Num1+Num2
print("Add=",add)
# Out:
# Add= 40

# %%
bmi = int(input('Enter the BMI Index:'))

if bmi < 20:
  print('underweight')
elif bmi < 30:
  print('normal weight')
else:
  print('Very overweight')
# Out:
# Enter the BMI Index:34
# Very overweight
